# %%
import numpsy as nsy

# %% [markdown]
# Declare a Unit

# %%
nsy.Unit("Farad", "F")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ddf4a3cb353b> in <module>
# ----> 1 nsy.Unit("Farad", "F")
#
# AttributeError: module 'numpsy' has no attribute 'Unit'
